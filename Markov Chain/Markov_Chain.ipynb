# %% [markdown]
# <a href="https://colab.research.google.com/github/hparmar3/hparmar3.github.io/blob/main/Markov_Chain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update && apt-get install -y libdb-dev
# !pip install gutenberg
import random
from collections import defaultdict

def build_markov_chain(text):
  words = text.split()
  chain = defaultdict(list)

  for i in range(len(words) - 1):
    chain[words[i]].append(words[i+1])

  return chain


def generate_text(chain, length=30):
  if not chain:
    return ""

  current_word = random.choice(list(chain.keys()))
  output = [current_word]

  for _ in range(length - 1):
    next_words = chain.get(current_word)
    if not next_words:
      current_word = random.choice(list(chain.keys()))
      output.append(current_word)
      continue

    current_word = random.choice(next_words)
    output.append(current_word)

  return " ". join(output)

from gutenberg.acquire import load_etext
from gutenberg.cleanup import strip_headers

# Amusements in Mathematics
text1 = strip_headers(load_etext(16713, mirror='http://www.gutenberg.org/')).strip()
# Anne of Green Gables
text2 = strip_headers(load_etext(45, mirror='http://www.gutenberg.org/')).strip()
# Don Quixote
text3 = strip_headers(load_etext(996, mirror='http://www.gutenberg.org/')).strip()

texts = [text1, text3]

combined_text = " ".join(texts)
combined_text = combined_text.lower()

chain = build_markov_chain(combined_text)

print(generate_text(chain, length = 10))
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 3,917 B in 1s (3,901 B/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ...
